# %% [markdown]
# # This Piece of Code is used to Generate & Export Images from CSV AFM data

# %%
import math
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import trange

import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure

# Presets for Plots 
#sns.set(style="darkgrid")
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ashis\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\ashis\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Exporting Set 1 of Polymer

# %%
# This Function is used to read the raw Data from the Folder; 
# The scan Data is stored within a Folder & the Path of this folder is given as input.
import re
import os
import numpy as np
import pandas as pd
np.random.seed(1000)


def reader(FILE_PATH, OUTPUT_PATH, POLY): # Input is given as the Path of the Folder Where all Data is stored. 

    # Change Directory of the Kernel
    os.chdir(FILE_PATH)
    #os.getcwd()
    
    # Storing the Path of each file within the Folder
    file_paths = []    
        
    # Checking if all files are TXT or not, Read only TXT files
    for file in os.listdir(): 
        if file.endswith(".txt"):
            file_paths.append(f"{FILE_PATH}\{file}")   

    # A Dictionary to store the Path of each File with an ID Number (assigned from 0 - max)
    a = {}  
    k = 0
    for ele in file_paths:
        a[k] = ele
        k+=1
    
    # A Dictionary to store the DATA
    b = {}   
    for i in range(len(a)):
        b[i] = pd.read_csv(a[i], delimiter = "\t", header = None) # Delimiter can be added as a feature or manually changed when required.
    
    # Taking the Dimension of the first file. (It is assumed that the Files will have same shape- has to be modded) # What happens if Data of Different Dimensions are give...? Something to be done in the future.
    D1, D2 = b[0].shape 
    
    # Creating a variable suitable for input to the Clustering Algorithm 
    X = np.random.rand(len(b), D1*D2) # (Number of elements, Dimension in 1D)
    for j in trange(len(X)):
        X[j] = b[j].to_numpy().reshape(1,-1)
       
    temp = a.copy()
    os.chdir(OUTPUT_PATH)
    
    for i in trange(len(temp)):

        SSS = temp[i].replace(FILE_PATH + "\\", " ")
        SSS = SSS.replace(".txt", " ")
        SSS = SSS.replace("P", "Thickness.") #H or P
        SSS = SSS.replace("A", "Area.")
        SSS = SSS.replace("S", "Size.")
        SSS = POLY + "_" + SSS

        plt.axis('off')
        plt.title(SSS)
        plt.imshow(b[i], aspect = 'equal', cmap = 'gray')
        plt.savefig(SSS+".png", aspect='equal', cmap = "gray", bbox_inches='tight',   pad_inches = 0)
        
        
    #Deletion to free up space
    #del a
    
    # returns the RESHAPED Data to be fed to the Clustering Algorithm & the Original Data for reference 
    print("Export to Images completed in Location", OUTPUT_PATH)
    print("A Total of ",i+1, "images were saved.")
    #return X, b

# %% [markdown]
# ### Runner

# %%
reader("W:\\Data PYTHON\\SET_1\\COMBINED", "W:\\Data PYTHON\\SET_1\\IMG_EXPORT", "P3HB") #P3HV
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 490.97it/s]
#   0%|                                                                                           | 0/52 [00:00<?, ?it/s]C:\Users\ashis\AppData\Local\Temp\ipykernel_1748\4274108387.py:59: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "aspect" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig(SSS+".png", aspect='equal', cmap = "gray", bbox_inches='tight',   pad_inches = 0)
# C:\Users\ashis\AppData\Local\Temp\ipykernel_1748\4274108387.py:59: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "cmap" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig(SSS+".png", aspect='equal', cmap = "gray", bbox_inches='tight',   pad_inches = 0)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 52/52 [00:57<00:00,  1.12s/it]
# Export to Images completed in Location W:\Data PYTHON\SET_1\IMG_EXPORT
# A Total of  51 images were saved.

# %% [markdown]
# -------------

# %% [markdown]
# # Export Set 2 of Polymer

# %%
# This Function is used to read the raw Data from the Folder; 
# The scan Data is stored within a Folder & the Path of this folder is given as input.
import re
import os
import numpy as np
import pandas as pd
np.random.seed(1000)


def reader_2(FILE_PATH, OUTPUT_PATH, POLY): # Input is given as the Path of the Folder Where all Data is stored. 

    # Change Directory of the Kernel
    os.chdir(FILE_PATH)
    #os.getcwd()
    
    # Storing the Path of each file within the Folder
    file_paths = []    
        
    # Checking if all files are TXT or not, Read only TXT files
    for file in os.listdir(): 
        if file.endswith(".txt"):
            file_paths.append(f"{FILE_PATH}\{file}")   

    # A Dictionary to store the Path of each File with an ID Number (assigned from 0 - max)
    a = {}  
    k = 0
    for ele in file_paths:
        a[k] = ele
        k+=1
    
    # A Dictionary to store the DATA
    b = {}   
    for i in range(len(a)):
        b[i] = pd.read_csv(a[i], delimiter = "\t", header = None) # Delimiter can be added as a feature or manually changed when required.
    
    # Taking the Dimension of the first file. (It is assumed that the Files will have same shape- has to be modded) # What happens if Data of Different Dimensions are give...? Something to be done in the future.
    D1, D2 = b[0].shape 
    
    # Creating a variable suitable for input to the Clustering Algorithm 
    X = np.random.rand(len(b), D1*D2) # (Number of elements, Dimension in 1D)
    for j in trange(len(X)):
        X[j] = b[j].to_numpy().reshape(1,-1)
       
    temp = a.copy()
    os.chdir(OUTPUT_PATH)
    
    for i in trange(len(temp)):

        SSS = temp[i].replace(FILE_PATH + "\\", " ")
        SSS = SSS.replace(".txt", " ")
        SSS = SSS.replace("H", "Thickness.") #H or P
        SSS = SSS.replace("A", "Area.")
        SSS = SSS.replace("S", "Size.")
        SSS = POLY + "_" + SSS

        plt.axis('off')
        plt.title(SSS)
        plt.imshow(b[i], aspect = 'equal', cmap = 'gray')
        plt.savefig(SSS+".png", aspect='equal', cmap = "gray", bbox_inches='tight',   pad_inches = 0)
        
        
    #Deletion to free up space
    #del a
    
    # returns the RESHAPED Data to be fed to the Clustering Algorithm & the Original Data for reference 
    print("Export to Images completed in Location", OUTPUT_PATH)
    print("A Total of ",i+1, "images were saved.")
    #return X, b

# %% [markdown]
# ### Missing Polymer 2, Area 1, Size 30

# %% [markdown]
# ### Runner Code

# %%
reader_2("W:\\Data PYTHON\\SET_2\\Combined_2", "W:\\Data PYTHON\\SET_2\\IMG_EXPORT_2", "P3HV") #P3HV
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 53/53 [00:00<00:00, 728.77it/s]
#   0%|                                                                                           | 0/53 [00:00<?, ?it/s]C:\Users\ashis\AppData\Local\Temp\ipykernel_1748\3333564384.py:59: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "aspect" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig(SSS+".png", aspect='equal', cmap = "gray", bbox_inches='tight',   pad_inches = 0)
# C:\Users\ashis\AppData\Local\Temp\ipykernel_1748\3333564384.py:59: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "cmap" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig(SSS+".png", aspect='equal', cmap = "gray", bbox_inches='tight',   pad_inches = 0)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 53/53 [01:13<00:00,  1.38s/it]
# Export to Images completed in Location W:\Data PYTHON\SET_2\IMG_EXPORT_2
# A Total of  53 images were saved.
